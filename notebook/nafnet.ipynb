# %%
import os
os.chdir("/kaggle/working")
os.system("rm -rf NAFNetfolk")
os.system("git clone https://github.com/HoangKhanhTung0111/NAFNetfolk.git")
os.chdir("/kaggle/working/NAFNetfolk")
print("CWD:", os.getcwd())
print("Files:", os.listdir("."))
# Out:
# Cloning into 'NAFNetfolk'...
# CWD: /kaggle/working/NAFNetfolk
# Files: ['demo', 'predict.py', 'experiments', 'skills', 'docs', 'options', 'benchmark_nafnet.py', 'scripts', 'LICENSE', 'figures', 'VERSION', 'requirements.txt', 'cog.yaml', 'setup.cfg', 'benchmark_and_eval.py', '.git', 'datasets', 'kaggle_benchmark_notebook.py', '.gitignore', 'readme.md', 'KAGGLE_GUIDE.py', 'basicsr', 'setup.py']

# %%
import os
os.makedirs("experiments/pretrained_models", exist_ok=True)
for f in os.listdir("/kaggle/input/datasets/hoangkhanhtung/nafnetmodel/"):
    src = f"/kaggle/input/datasets/hoangkhanhtung/nafnetmodel/{f}"
    dst = f"experiments/pretrained_models/{f}"
    if not os.path.exists(dst):
        os.symlink(src, dst)

os.makedirs("datasets/GoPro/test", exist_ok=True)
if not os.path.exists("datasets/GoPro/test/input.lmdb"):
    os.symlink("/kaggle/input/datasets/hoangkhanhtung/goprodata/GoPro/test/input.lmdb", "datasets/GoPro/test/input.lmdb")
    os.symlink("/kaggle/input/datasets/hoangkhanhtung/goprodata/GoPro/test/target.lmdb", "datasets/GoPro/test/target.lmdb")

os.makedirs("datasets/SIDD/val", exist_ok=True)
if not os.path.exists("datasets/SIDD/val/input_crops.lmdb"):
    os.symlink("/kaggle/input/datasets/hoangkhanhtung/sidddata/SIDD/val/input_crops.lmdb", "datasets/SIDD/val/input_crops.lmdb")
    os.symlink("/kaggle/input/datasets/hoangkhanhtung/sidddata/SIDD/val/gt_crops.lmdb", "datasets/SIDD/val/gt_crops.lmdb")

print("Done!")
# !ls experiments/pretrained_models/
# Out:
# Done!
# NAFNet-GoPro-width32.pth  NAFNet-SIDD-width32.pth  README.md
# NAFNet-GoPro-width64.pth  NAFNet-SIDD-width64.pth

# %%
import os
os.chdir("/kaggle/working/NAFNetfolk")
# !pip install -q -r requirements.txt
# !pip install -q ptflops
import sys; sys.path.insert(0, '.')
# !python benchmark_and_eval.py --mode all
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.7/344.7 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 76.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 17.1 MB/s eta 0:00:00
# ...
#   BENCHMARK: Parameters, FLOPs, Latency, VRAM
# ...
# GPU: Tesla T4
# VRAM: 14.6 GB
# PyTorch: 2.10.0+cu128
#
# --- NAFNet-GoPro-w32 ---
#   Weights: loaded
#   Params: 17.11 M
#   MACs 256x256: 16.10 G
#   MACs 720x1280: 260.29 G
#   Lat 256x256: 35.84 ms (27.9 FPS) | VRAM: 130 MB
#   Lat 720x1280: 435.13 ms (2.3 FPS) | VRAM: 980 MB
#
# --- NAFNet-GoPro-w64 ---
#   Weights: loaded
#   Params: 67.89 M
#   MACs 256x256: 63.33 G

# %%
import os
os.chdir("/kaggle/working/NAFNetfolk")
# !git pull
# !python benchmark_and_eval.py --mode all
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 647 bytes | 647.00 KiB/s, done.
# From https://github.com/HoangKhanhTung0111/NAFNetfolk
#    dfbfc98..b26e87a  main       -> origin/main
# Updating dfbfc98..b26e87a
# Fast-forward
#  benchmark_and_eval.py | 17 +++++++++++++++++
#  1 file changed, 17 insertions(+)
# ...
#   BENCHMARK: Parameters, FLOPs, Latency, VRAM
# ...
# GPU: Tesla T4
# VRAM: 14.6 GB
# PyTorch: 2.10.0+cu128
#
# --- NAFNet-GoPro-w32 ---
#   Weights: loaded
#   Params: 17.11 M
#   MACs 256x256: 14.61 G
#   MACs 720x1280: 205.44 G
#   Lat 256x256: 35.60 ms (28.1 FPS) | VRAM: 130 MB
#   Lat 720x1280: 423.68 ms (2.4 FPS) | VRAM: 980 MB
#
# --- NAFNet-GoPro-w64 ---
#   Weights: loaded
#   Params: 67.89 M
#   MACs 256x256: 58.21 G
#   MACs 720x1280: 818.56 G
# ...
